# %% [markdown]
# # Probabilistic forecasting I: Temperature
# ## Kaggle Competition hosted by Carl McBride Ellis
# ## Catboost Multiquantiles Regression - Conformalized Quantile Regression
#
# Submission Score: xxxxxx
#
# ### https://www.linkedin.com/in/stephane-degeye-b460a5221/

# %% [markdown]
# # Some Librairies

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.2.5)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.7.5)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.10/site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.2.3)

# %%
import utility_script_crps_score as us
# help(us.crps)

# Data Structure
import numpy as np
import pandas as pd

# Model
from catboost import CatBoostRegressor

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# Utils
from sklearn.model_selection import train_test_split

# Error Handling
import warnings
warnings.filterwarnings("ignore")

# Plot
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

plt.style.use('ggplot')
plt.rcParams.update(**{'figure.dpi':150})

# %matplotlib inline

# %% [markdown]
# # A. Data Loading

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# # Folder related to n-beats data
# folder_id = 'kaggle/probabilistic-forecasting-i-temperature'

# # Full path
# folder_path = '/content/gdrive/My Drive/'+ folder_id

# train_df = pd.read_csv(folder_path + '/dataset/train.csv')
# kaggle_test_df = pd.read_csv(folder_path + '/dataset/test.csv')
# submission_df = pd.read_csv(folder_path + '/submission/sample_submission.csv')

# %%
# Load the dataset
train_df = pd.read_csv('/kaggle/input/probabilistic-forecasting-i-temperature/train_and_Public.csv')
kaggle_test_df = pd.read_csv('/kaggle/input/probabilistic-forecasting-i-temperature/test.csv')
submission_df = pd.read_csv('/kaggle/input/probabilistic-forecasting-i-temperature/sample_submission.csv')

# %%
train_df
# Out:
#           id                 date  feature_AA  feature_AB  feature_BA  \
# 0          0  2016-07-01 00:00:00       5.827       2.009       1.599
# 1          1  2016-07-01 00:15:00       5.760       2.076       1.492
# 2          2  2016-07-01 00:30:00       5.760       1.942       1.492
# 3          3  2016-07-01 00:45:00       5.760       1.942       1.492
# 4          4  2016-07-01 01:00:00       5.693       2.076       1.492
# ...      ...                  ...         ...         ...         ...
# 67003  67003  2018-05-29 22:45:00      13.329       3.885       8.457
# 67004  67004  2018-05-29 23:00:00      14.468       5.023       9.808
# 67005  67005  2018-05-29 23:15:00      15.539       5.291      10.909
# 67006  67006  2018-05-29 23:30:00      14.066       4.957       9.772
# 67007  67007  2018-05-29 23:45:00      14.535       5.358      10.163
#
#        feature_BB  feature_CA  feature_CB  Temperature
# 0           0.462       4.203       1.340    30.531000
# 1           0.426       4.264       1.401    30.459999
# 2           0.391       4.234       1.310    30.038000
# 3           0.426       4.234       1.310    27.013000
# 4           0.426       4.142       1.371    27.787001
# ...           ...         ...         ...          ...
# 67003       1.954       4.630       1.401    10.130000
# 67004       2.630       4.538       1.432    10.130000
# 67005       3.056       4.569       1.340    10.271000
# 67006       3.020       4.447       1.401    10.271000
# 67007       3.056       4.630       1.584    10.763000
#
# [67008 rows x 9 columns]

# %%
kaggle_test_df
# Out:
#          id                 date  feature_AA  feature_AB  feature_BA  \
# 0     64320  2018-05-02 00:00:00      14.133       2.076       9.346
# 1     64321  2018-05-02 00:15:00      12.123       1.541       7.818
# 2     64322  2018-05-02 00:30:00      12.525       1.741       8.209
# 3     64323  2018-05-02 00:45:00      12.324       1.942       7.747
# 4     64324  2018-05-02 01:00:00      14.602       1.407       9.630
# ...     ...                  ...         ...         ...         ...
# 5355  69675  2018-06-26 18:45:00       9.310       3.550       5.437
# 5356  69676  2018-06-26 19:00:00      10.114       3.550       6.183
# 5357  69677  2018-06-26 19:15:00      10.784       3.349       7.000
# 5358  69678  2018-06-26 19:30:00      11.655       3.617       7.533
# 5359  69679  2018-06-26 19:45:00      12.994       3.818       8.244
#
#       feature_BB  feature_CA  feature_CB
# 0         -0.036       4.538       1.279
# 1         -0.746       4.538       1.249
# 2         -0.284       4.477       1.279
# 3          0.249       4.630       1.371
# 4         -0.320       4.477       1.310
# ...          ...         ...         ...
# 5355       1.670       3.868       1.462
# 5356       1.564       3.716       1.462
# 5357       1.635       3.746       1.432
# 5358       1.706       4.173       1.523
# 5359       1.777       4.721       1.523
#
# [5360 rows x 8 columns]

# %% [markdown]
# # B. Data Preparation

# %%
train_df['date'] = pd.to_datetime(train_df['date'])

# %%
kaggle_test_df['date'] = pd.to_datetime(kaggle_test_df['date'])

# %% [markdown]
# # C. Exploratory Data Analysis

# %% [markdown]
# ## Shape of Dataframe

# %%
num_rec_train = train_df.shape[0]
print(f'Train dataframe contains {num_rec_train} records belongings to {round(num_rec_train / 96, 1)} days')

num_rec_test = kaggle_test_df.shape[0]
print(f'Test dataframe contains {num_rec_test} records belongings to {round(num_rec_test / 96, 1)} days')
# Out:
# Train dataframe contains 67008 records belongings to 698.0 days
# Test dataframe contains 5360 records belongings to 55.8 days

# %% [markdown]
# ## Missing Values

# %%
# Detecting missing values in train_df
missing_values = train_df.isnull().sum()

print("Missing values in each column of train_df:")
print(missing_values)

# Detecting missing values in kaggle_test_df
missing_values = kaggle_test_df.isnull().sum()

print("Missing values in each column of kaggle_test_df:")
print(missing_values)
# Out:
# Missing values in each column of train_df:
# id             0
# date           0
# feature_AA     0
# feature_AB     0
# feature_BA     0
# feature_BB     0
# feature_CA     0
# feature_CB     0
# Temperature    0
# dtype: int64
# Missing values in each column of kaggle_test_df:
# id            0
# date          0
# feature_AA    0
# feature_AB    0
# feature_BA    0
# feature_BB    0
# feature_CA    0
# feature_CB    0
# dtype: int64

# %% [markdown]
# ## Tabular View

# %%
train_df.head()
# Out:
#    id                date  feature_AA  feature_AB  feature_BA  feature_BB  \
# 0   0 2016-07-01 00:00:00       5.827       2.009       1.599       0.462
# 1   1 2016-07-01 00:15:00       5.760       2.076       1.492       0.426
# 2   2 2016-07-01 00:30:00       5.760       1.942       1.492       0.391
# 3   3 2016-07-01 00:45:00       5.760       1.942       1.492       0.426
# 4   4 2016-07-01 01:00:00       5.693       2.076       1.492       0.426
#
#    feature_CA  feature_CB  Temperature
# 0       4.203       1.340    30.531000
# 1       4.264       1.401    30.459999
# 2       4.234       1.310    30.038000
# 3       4.234       1.310    27.013000
# 4       4.142       1.371    27.787001

# %%
kaggle_test_df.head()
# Out:
#       id                date  feature_AA  feature_AB  feature_BA  feature_BB  \
# 0  64320 2018-05-02 00:00:00      14.133       2.076       9.346      -0.036
# 1  64321 2018-05-02 00:15:00      12.123       1.541       7.818      -0.746
# 2  64322 2018-05-02 00:30:00      12.525       1.741       8.209      -0.284
# 3  64323 2018-05-02 00:45:00      12.324       1.942       7.747       0.249
# 4  64324 2018-05-02 01:00:00      14.602       1.407       9.630      -0.320
#
#    feature_CA  feature_CB
# 0       4.538       1.279
# 1       4.538       1.249
# 2       4.477       1.279
# 3       4.630       1.371
# 4       4.477       1.310

# %% [markdown]
# ## Data Distribution

# %%
# Set the theme for the plot
sns.set_theme(style="whitegrid")

# Create a histogram of the total bill
plt.figure(figsize=(10, 6))
sns.histplot(train_df['Temperature'], bins=30, kde=True, color='blue')

# Adding titles and labels
plt.title('Distribution of Temperature', fontsize=16)
plt.xlabel('Temperature', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# ## Check Stationarity

# %%
ADF_result = adfuller(train_df['Temperature'])

print(f'ADF Statistic: {ADF_result[0]}')
print(f'p-value: {ADF_result[1]}')
# Out:
# ADF Statistic: -4.103689681383457
# p-value: 0.0009550125795118824

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> [Stationarity] </b> p-value < 0.05, so we can reject the Null Hypothesis, Time Series is Stationary!</div>

# %% [markdown]
# ## Partial Autocorrelation

# %%
plot_pacf(train_df['feature_AA'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_AA', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_AA')

# %%
plot_pacf(train_df['feature_AB'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_AB', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_AB')

# %%
plot_pacf(train_df['feature_BA'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_BA', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_BA')

# %%
plot_pacf(train_df['feature_BB'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_BB', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_BB')

# %%
plot_pacf(train_df['feature_CA'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_CA', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_CA')

# %%
plot_pacf(train_df['feature_CB'], lags=100)
plt.ylim(-0.2, 1.1)
plt.tight_layout

# Adding titles and labels
plt.title('Partial Autocorrelation feature_CB', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation feature_CB')

# %% [markdown]
# # D. Features Engineering

# %%
train_df['year'] = train_df['date'].dt.year.astype(int)
train_df['month'] = train_df['date'].dt.month.astype(int)
train_df['day'] = train_df['date'].dt.day.astype(int)
train_df['hour'] = train_df['date'].dt.hour.astype(int)
train_df['week_of_year'] = train_df['date'].apply(lambda x: x.isocalendar()[1])
train_df['day_of_week'] = train_df['date'].dt.dayofweek.astype(int)
train_df['id'] = train_df['id'].astype(float)

train_df['feature_AA_lag_1'] = train_df['feature_AA'].shift(1)
train_df['feature_AA_lag_2'] = train_df['feature_AA'].shift(2)
train_df['feature_AA_lag_4'] = train_df['feature_AA'].shift(4)
train_df['feature_AA_lag_5'] = train_df['feature_AA'].shift(5)
train_df['feature_AA_lag_6'] = train_df['feature_AA'].shift(6)
train_df['feature_AA_lag_97'] = train_df['feature_AA'].shift(97)
train_df['feature_AA_lag_98'] = train_df['feature_AA'].shift(98)

train_df['feature_AB_lag_1'] = train_df['feature_AB'].shift(1)
train_df['feature_AB_lag_2'] = train_df['feature_AB'].shift(2)
train_df['feature_AB_lag_3'] = train_df['feature_AB'].shift(3)
train_df['feature_AB_lag_98'] = train_df['feature_AB'].shift(98)

train_df['feature_CA_lag_1'] = train_df['feature_CA'].shift(1)
train_df['feature_CA_lag_36'] = train_df['feature_CA'].shift(36)
train_df['feature_CA_lag_97'] = train_df['feature_CA'].shift(97)
train_df['feature_CA_lag_98'] = train_df['feature_CA'].shift(98)

train_df['feature_CB_lag_1'] = train_df['feature_CB'].shift(1)
train_df['feature_CB_lag_2'] = train_df['feature_CB'].shift(2)
train_df['feature_CB_lag_3'] = train_df['feature_CB'].shift(3)

# Create Fourier terms for dayly seasonality
train_fourier_day = np.sin(2 * np.pi * np.arange(len(train_df)) / 96)
train_fourier_day += np.cos(2 * np.pi * np.arange(len(train_df)) / 96)
train_df['fourier_terms_day'] = train_fourier_day

# Create Fourier terms for weekly seasonality
train_fourier_week = np.sin(2 * np.pi * np.arange(len(train_df)) / 96*7)
train_fourier_week += np.cos(2 * np.pi * np.arange(len(train_df)) / 96*7)
train_df['fourier_terms_week'] = train_fourier_week

train_df.drop('feature_BA', axis=1, inplace=True)
train_df.drop('feature_BB', axis=1, inplace=True)
train_df.drop('date', axis=1, inplace=True)

kaggle_test_df['year'] = kaggle_test_df['date'].dt.year.astype(int)
kaggle_test_df['month'] = kaggle_test_df['date'].dt.month.astype(int)
kaggle_test_df['day'] = kaggle_test_df['date'].dt.day.astype(int)
kaggle_test_df['hour'] = kaggle_test_df['date'].dt.hour.astype(int)
kaggle_test_df['week_of_year'] = kaggle_test_df['date'].apply(lambda x: x.isocalendar()[1])
kaggle_test_df['day_of_week'] = kaggle_test_df['date'].dt.dayofweek.astype(int)
kaggle_test_df['id'] = kaggle_test_df['id'].astype(float)

kaggle_test_df['feature_AA_lag_1'] = kaggle_test_df['feature_AA'].shift(1)
kaggle_test_df['feature_AA_lag_2'] = kaggle_test_df['feature_AA'].shift(2)
kaggle_test_df['feature_AA_lag_4'] = kaggle_test_df['feature_AA'].shift(4)
kaggle_test_df['feature_AA_lag_5'] = kaggle_test_df['feature_AA'].shift(5)
kaggle_test_df['feature_AA_lag_6'] = kaggle_test_df['feature_AA'].shift(6)
kaggle_test_df['feature_AA_lag_97'] = kaggle_test_df['feature_AA'].shift(97)
kaggle_test_df['feature_AA_lag_98'] = kaggle_test_df['feature_AA'].shift(98)

kaggle_test_df['feature_AB_lag_1'] = kaggle_test_df['feature_AB'].shift(1)
kaggle_test_df['feature_AB_lag_2'] = kaggle_test_df['feature_AB'].shift(2)
kaggle_test_df['feature_AB_lag_3'] = kaggle_test_df['feature_AB'].shift(3)
kaggle_test_df['feature_AB_lag_98'] = kaggle_test_df['feature_AB'].shift(98)

kaggle_test_df['feature_CA_lag_1'] = kaggle_test_df['feature_CA'].shift(1)
kaggle_test_df['feature_CA_lag_36'] = kaggle_test_df['feature_CA'].shift(36)
kaggle_test_df['feature_CA_lag_97'] = kaggle_test_df['feature_CA'].shift(97)
kaggle_test_df['feature_CA_lag_98'] = kaggle_test_df['feature_CA'].shift(98)

kaggle_test_df['feature_CB_lag_1'] = kaggle_test_df['feature_CB'].shift(1)
kaggle_test_df['feature_CB_lag_2'] = kaggle_test_df['feature_CB'].shift(2)
kaggle_test_df['feature_CB_lag_3'] = kaggle_test_df['feature_CB'].shift(3)


# Create Fourier terms for dayly seasonality
kaggle_test_fourier_day = np.sin(2 * np.pi * np.arange(len(kaggle_test_df)) / 96)
kaggle_test_fourier_day += np.cos(2 * np.pi * np.arange(len(kaggle_test_df)) / 96)
kaggle_test_df['fourier_terms_day'] = kaggle_test_fourier_day

# Create Fourier terms for weekly seasonality
kaggle_test_fourier_week = np.sin(2 * np.pi * np.arange(len(kaggle_test_df)) / 96*7)
kaggle_test_fourier_week += np.cos(2 * np.pi * np.arange(len(kaggle_test_df)) / 96*7)
kaggle_test_df['fourier_terms_week'] = kaggle_test_fourier_week

kaggle_test_df.drop('feature_BA', axis=1, inplace=True)
kaggle_test_df.drop('feature_BB', axis=1, inplace=True)
kaggle_test_df.drop('date', axis=1, inplace=True)

# %%
train_df
# Out:
#             id  feature_AA  feature_AB  feature_CA  feature_CB  Temperature  \
# 0          0.0       5.827       2.009       4.203       1.340    30.531000
# 1          1.0       5.760       2.076       4.264       1.401    30.459999
# 2          2.0       5.760       1.942       4.234       1.310    30.038000
# 3          3.0       5.760       1.942       4.234       1.310    27.013000
# 4          4.0       5.693       2.076       4.142       1.371    27.787001
# ...        ...         ...         ...         ...         ...          ...
# 67003  67003.0      13.329       3.885       4.630       1.401    10.130000
# 67004  67004.0      14.468       5.023       4.538       1.432    10.130000
# 67005  67005.0      15.539       5.291       4.569       1.340    10.271000
# 67006  67006.0      14.066       4.957       4.447       1.401    10.271000
# 67007  67007.0      14.535       5.358       4.630       1.584    10.763000
#
#        year  month  day  hour  ...  feature_AB_lag_98  feature_CA_lag_1  \
# 0      2016      7    1     0  ...                NaN               NaN
# 1      2016      7    1     0  ...                NaN             4.203
# 2      2016      7    1     0  ...                NaN             4.264
# 3      2016      7    1     0  ...                NaN             4.234
# 4      2016      7    1     1  ...                NaN             4.234
# ...     ...    ...  ...   ...  ...                ...               ...
# 67003  2018      5   29    22  ...              4.287             4.752
# 67004  2018      5   29    23  ...              4.689             4.630
# 67005  2018      5   29    23  ...              4.488             4.538
# 67006  2018      5   29    23  ...              5.224             4.569
# 67007  2018      5   29    23  ...              4.622             4.447
#
#        feature_CA_lag_36  feature_CA_lag_97  feature_CA_lag_98  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 67003              2.559              4.569              4.630
# 67004              2.711              4.508              4.569
# 67005              2.680              4.386              4.508
# 67006              2.711              4.325              4.386
# 67007              2.619              4.295              4.325
#
#        feature_CB_lag_1  feature_CB_lag_2  feature_CB_lag_3  \
# 0                   NaN               NaN               NaN
# 1                 1.340               NaN               NaN
# 2                 1.401             1.340               NaN
# 3                 1.310             1.401             1.340
# 4                 1.310             1.310             1.401
# ...                 ...               ...               ...
# 67003             1.340             1.432             1.066
# 67004             1.401             1.340             1.432
# 67005             1.432             1.401             1.340
# 67006             1.340             1.432             1.401
# 67007             1.401             1.340             1.432
#
#        fourier_terms_day  fourier_terms_week
# 0               1.000000            1.000000
# 1               1.063262            1.339161
# 2               1.121971            1.402115
# 3               1.175876            1.175876
# 4               1.224745            0.707107
# ...                  ...                 ...
# 67003           0.625491           -1.411186
# 67004           0.707107           -1.224745
# 67005           0.785695           -0.785695
# 67006           0.860919           -0.184592
# 67007           0.932456            0.454584
#
# [67008 rows x 32 columns]

# %%
kaggle_test_df
# Out:
#            id  feature_AA  feature_AB  feature_CA  feature_CB  year  month  \
# 0     64320.0      14.133       2.076       4.538       1.279  2018      5
# 1     64321.0      12.123       1.541       4.538       1.249  2018      5
# 2     64322.0      12.525       1.741       4.477       1.279  2018      5
# 3     64323.0      12.324       1.942       4.630       1.371  2018      5
# 4     64324.0      14.602       1.407       4.477       1.310  2018      5
# ...       ...         ...         ...         ...         ...   ...    ...
# 5355  69675.0       9.310       3.550       3.868       1.462  2018      6
# 5356  69676.0      10.114       3.550       3.716       1.462  2018      6
# 5357  69677.0      10.784       3.349       3.746       1.432  2018      6
# 5358  69678.0      11.655       3.617       4.173       1.523  2018      6
# 5359  69679.0      12.994       3.818       4.721       1.523  2018      6
#
#       day  hour  week_of_year  ...  feature_AB_lag_98  feature_CA_lag_1  \
# 0       2     0            18  ...                NaN               NaN
# 1       2     0            18  ...                NaN             4.538
# 2       2     0            18  ...                NaN             4.538
# 3       2     0            18  ...                NaN             4.477
# 4       2     1            18  ...                NaN             4.630
# ...   ...   ...           ...  ...                ...               ...
# 5355   26    18            26  ...              3.215             3.746
# 5356   26    19            26  ...              3.081             3.868
# 5357   26    19            26  ...              2.813             3.716
# 5358   26    19            26  ...              2.813             3.746
# 5359   26    19            26  ...              3.081             4.173
#
#       feature_CA_lag_36  feature_CA_lag_97  feature_CA_lag_98  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 5355              3.503              3.320              3.290
# 5356              3.564              3.350              3.320
# 5357              3.868              3.320              3.350
# 5358              3.533              3.716              3.320
# 5359              3.564              3.990              3.716
#
#       feature_CB_lag_1  feature_CB_lag_2  feature_CB_lag_3  fourier_terms_day  \
# 0                  NaN               NaN               NaN           1.000000
# 1                1.279               NaN               NaN           1.063262
# 2                1.249             1.279               NaN           1.121971
# 3                1.279             1.249             1.279           1.175876
# 4                1.371             1.279             1.249           1.224745
# ...                ...               ...               ...                ...
# 5355             1.492             1.371             1.432          -0.785695
# 5356             1.462             1.492             1.371          -0.707107
# 5357             1.462             1.462             1.492          -0.625491
# 5358             1.432             1.462             1.462          -0.541196
# 5359             1.523             1.432             1.462          -0.454584
#
#       fourier_terms_week
# 0               1.000000
# 1               1.339161
# 2               1.402115
# 3               1.175876
# 4               0.707107
# ...                  ...
# 5355           -0.785695
# 5356           -1.224745
# 5357           -1.411186
# 5358           -1.306563
# 5359           -0.932456
#
# [5360 rows x 31 columns]

# %% [markdown]
# ## Pearson Pairwise Correlation

# %%
pear_corr = train_df.drop(['id'], axis=1).corr(method='pearson')
pear_corr.style.background_gradient(cmap='Greens', axis=0)
# Out:
# <style type="text/css">
# #T_7bccc_row0_col0, #T_7bccc_row1_col1, #T_7bccc_row2_col2, #T_7bccc_row3_col3, #T_7bccc_row4_col4, #T_7bccc_row5_col5, #T_7bccc_row6_col6, #T_7bccc_row7_col7, #T_7bccc_row8_col8, #T_7bccc_row9_col9, #T_7bccc_row10_col10, #T_7bccc_row11_col11, #T_7bccc_row12_col12, #T_7bccc_row13_col13, #T_7bccc_row14_col14, #T_7bccc_row15_col15, #T_7bccc_row16_col16, #T_7bccc_row17_col17, #T_7bccc_row18_col18, #T_7bccc_row19_col19, #T_7bccc_row20_col20, #T_7bccc_row21_col21, #T_7bccc_row22_col22, #T_7bccc_row23_col23, #T_7bccc_row24_col24, #T_7bccc_row25_col25, #T_7bccc_row26_col26, #T_7bccc_row27_col27, #T_7bccc_row28_col28, #T_7bccc_row29_col29, #T_7bccc_row30_col30 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col1, #T_7bccc_row0_col8, #T_7bccc_row0_col18, #T_7bccc_row0_col19, #T_7bccc_row0_col24, #T_7bccc_row11_col21, #T_7bccc_row11_col25, #T_7bccc_row15_col24, #T_7bccc_row17_col18, #T_7bccc_row17_col19, #T_7bccc_row17_col20, #T_7bccc_row19_col13 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_7bccc_row0_col2, #T_7bccc_row2_col29, #T_7bccc_row11_col2, #T_7bccc_row11_col22, #T_7bccc_row12_col22, #T_7bccc_row16_col24, #T_7bccc_row17_col24, #T_7bccc_row17_col25, #T_7bccc_row22_col8, #T_7bccc_row22_col29, #T_7bccc_row24_col29, #T_7bccc_row25_col8 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_7bccc_row0_col3, #T_7bccc_row0_col26, #T_7bccc_row5_col1, #T_7bccc_row7_col3, #T_7bccc_row7_col26, #T_7bccc_row7_col27, #T_7bccc_row11_col26, #T_7bccc_row11_col27, #T_7bccc_row11_col28 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_7bccc_row0_col4, #T_7bccc_row0_col6, #T_7bccc_row0_col9, #T_7bccc_row4_col20, #T_7bccc_row11_col4, #T_7bccc_row11_col6, #T_7bccc_row11_col9, #T_7bccc_row12_col6, #T_7bccc_row12_col9, #T_7bccc_row13_col6, #T_7bccc_row13_col9, #T_7bccc_row14_col6, #T_7bccc_row14_col9, #T_7bccc_row15_col6, #T_7bccc_row15_col9, #T_7bccc_row16_col4, #T_7bccc_row22_col15 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_7bccc_row0_col5, #T_7bccc_row11_col5, #T_7bccc_row11_col20, #T_7bccc_row12_col5, #T_7bccc_row13_col5, #T_7bccc_row14_col5, #T_7bccc_row14_col24, #T_7bccc_row15_col5, #T_7bccc_row15_col25, #T_7bccc_row16_col5, #T_7bccc_row17_col5, #T_7bccc_row18_col13, #T_7bccc_row23_col18 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_7bccc_row0_col7, #T_7bccc_row10_col3, #T_7bccc_row10_col26, #T_7bccc_row10_col27, #T_7bccc_row11_col7, #T_7bccc_row12_col7, #T_7bccc_row13_col7, #T_7bccc_row14_col7, #T_7bccc_row15_col7, #T_7bccc_row21_col7, #T_7bccc_row30_col3 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_7bccc_row0_col10, #T_7bccc_row5_col12, #T_7bccc_row5_col17, #T_7bccc_row6_col28, #T_7bccc_row8_col3, #T_7bccc_row8_col10, #T_7bccc_row8_col16, #T_7bccc_row8_col26, #T_7bccc_row9_col2, #T_7bccc_row9_col3, #T_7bccc_row9_col10, #T_7bccc_row9_col22, #T_7bccc_row9_col23, #T_7bccc_row9_col24, #T_7bccc_row9_col25, #T_7bccc_row9_col26, #T_7bccc_row9_col27, #T_7bccc_row10_col7, #T_7bccc_row11_col10, #T_7bccc_row12_col10, #T_7bccc_row13_col10, #T_7bccc_row14_col10, #T_7bccc_row15_col10, #T_7bccc_row16_col7, #T_7bccc_row17_col7, #T_7bccc_row29_col10, #T_7bccc_row29_col26, #T_7bccc_row30_col10 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_7bccc_row0_col11, #T_7bccc_row11_col0, #T_7bccc_row11_col12, #T_7bccc_row12_col11, #T_7bccc_row14_col13, #T_7bccc_row16_col17, #T_7bccc_row17_col16 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col12, #T_7bccc_row12_col0, #T_7bccc_row13_col12 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col13, #T_7bccc_row15_col12 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col14, #T_7bccc_row11_col15 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col15 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col16, #T_7bccc_row11_col17, #T_7bccc_row12_col16, #T_7bccc_row16_col0, #T_7bccc_row17_col11, #T_7bccc_row17_col13 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col17, #T_7bccc_row16_col13, #T_7bccc_row17_col0, #T_7bccc_row17_col14 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col20, #T_7bccc_row17_col1 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_7bccc_row0_col21, #T_7bccc_row0_col25, #T_7bccc_row16_col1, #T_7bccc_row16_col18, #T_7bccc_row16_col19, #T_7bccc_row16_col20, #T_7bccc_row20_col13, #T_7bccc_row23_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_7bccc_row0_col22, #T_7bccc_row2_col3, #T_7bccc_row3_col6, #T_7bccc_row3_col9, #T_7bccc_row13_col2, #T_7bccc_row14_col22, #T_7bccc_row22_col26, #T_7bccc_row24_col15, #T_7bccc_row25_col14, #T_7bccc_row26_col6, #T_7bccc_row26_col9, #T_7bccc_row27_col6, #T_7bccc_row27_col9, #T_7bccc_row28_col6, #T_7bccc_row28_col9 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_7bccc_row0_col23, #T_7bccc_row7_col24, #T_7bccc_row7_col25, #T_7bccc_row19_col8, #T_7bccc_row21_col8, #T_7bccc_row23_col17 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_7bccc_row0_col27, #T_7bccc_row0_col28, #T_7bccc_row5_col15, #T_7bccc_row15_col30, #T_7bccc_row30_col28 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_7bccc_row0_col29 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_7bccc_row0_col30, #T_7bccc_row1_col30, #T_7bccc_row5_col20, #T_7bccc_row19_col30, #T_7bccc_row21_col30, #T_7bccc_row27_col30 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_7bccc_row1_col0, #T_7bccc_row1_col24, #T_7bccc_row1_col25, #T_7bccc_row3_col15, #T_7bccc_row7_col18, #T_7bccc_row7_col21, #T_7bccc_row18_col11, #T_7bccc_row18_col25, #T_7bccc_row20_col12, #T_7bccc_row20_col24 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_7bccc_row1_col2, #T_7bccc_row18_col22, #T_7bccc_row21_col3, #T_7bccc_row21_col24, #T_7bccc_row21_col26, #T_7bccc_row21_col27, #T_7bccc_row21_col28, #T_7bccc_row24_col12, #T_7bccc_row25_col12 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_7bccc_row1_col3, #T_7bccc_row2_col1, #T_7bccc_row3_col22, #T_7bccc_row8_col9, #T_7bccc_row10_col9, #T_7bccc_row18_col3, #T_7bccc_row18_col26, #T_7bccc_row19_col3, #T_7bccc_row19_col26, #T_7bccc_row19_col27, #T_7bccc_row19_col28, #T_7bccc_row20_col26, #T_7bccc_row20_col27, #T_7bccc_row26_col2, #T_7bccc_row27_col22, #T_7bccc_row29_col9, #T_7bccc_row30_col9 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_7bccc_row1_col4, #T_7bccc_row4_col6, #T_7bccc_row18_col4 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_7bccc_row1_col5, #T_7bccc_row18_col5, #T_7bccc_row19_col5, #T_7bccc_row20_col5, #T_7bccc_row25_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_7bccc_row1_col6, #T_7bccc_row18_col6, #T_7bccc_row19_col6, #T_7bccc_row20_col6, #T_7bccc_row21_col6 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_7bccc_row1_col7, #T_7bccc_row18_col7, #T_7bccc_row19_col7, #T_7bccc_row20_col7, #T_7bccc_row30_col26 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_7bccc_row1_col8, #T_7bccc_row4_col13, #T_7bccc_row4_col24, #T_7bccc_row4_col25, #T_7bccc_row9_col13, #T_7bccc_row10_col18, #T_7bccc_row10_col21, #T_7bccc_row19_col16 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_7bccc_row1_col9, #T_7bccc_row18_col9, #T_7bccc_row19_col4, #T_7bccc_row19_col9, #T_7bccc_row20_col4, #T_7bccc_row20_col9, #T_7bccc_row21_col9 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_7bccc_row1_col10, #T_7bccc_row4_col10, #T_7bccc_row18_col10, #T_7bccc_row19_col10, #T_7bccc_row20_col10 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_7bccc_row1_col11, #T_7bccc_row5_col24, #T_7bccc_row5_col25, #T_7bccc_row7_col19, #T_7bccc_row19_col12, #T_7bccc_row21_col17 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_7bccc_row1_col12, #T_7bccc_row21_col22 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_7bccc_row1_col13, #T_7bccc_row12_col1, #T_7bccc_row12_col18, #T_7bccc_row12_col20, #T_7bccc_row12_col24, #T_7bccc_row13_col25, #T_7bccc_row16_col2, #T_7bccc_row17_col2, #T_7bccc_row17_col22, #T_7bccc_row25_col0 {
#   background-color: #b8e3b2;
#   color: #000000;

# %% [markdown]
# # E. Modeling

# %% [markdown]
# ## Hyperparameters

# %%
quantile_mapping = {
    95: ['0.025', '0.975'],
    90: ['0.05', '0.95'],
    80: ['0.10', '0.90'],
    70: ['0.15', '0.85'],
    60: ['0.20', '0.80'],
    50: ['0.25', '0.75'],
    40: ['0.30', '0.70'],
    30: ['0.35', '0.65'],
    20: ['0.40', '0.60'],
    10: ['0.45', '0.55']
}

# %%
quantiles = [0.025, 0.05,0.10,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50,0.55,0.60,0.65,0.70,0.75,0.80,0.85,0.90,0.95,0.975]
levels = np.array([95, 90, 80, 70, 60, 50, 40, 30, 20, 10])

# %%
quantile_str = str(quantiles).replace('[','').replace(']','')

# %%
submission_val_df = submission_df[:5360].copy()

# %% [markdown]
# ## Dataset Splitting

# %%
X = train_df.drop('Temperature', axis=1)
y = train_df['Temperature']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=5360)

# %%
X_proper_train, X_cal, y_proper_train, y_cal = train_test_split(X_train, y_train, test_size=0.12, random_state=1)

# %% [markdown]
# ## Model Definition

# %%
# model definition
multiquantiles_model = CatBoostRegressor(
                                        loss_function = f'MultiQuantile:alpha={quantile_str}',
                                        thread_count = -1,
                                        bootstrap_type =  "Bernoulli",
                                        sampling_frequency= 'PerTree',
                                        iterations = 10000,
                                     **{'learning_rate': 0.015,
                                          'max_depth': 10,
                                          'subsample': 0.75,
                                          'colsample_bylevel': 0.9,
                                          'min_data_in_leaf': 37},
                                           verbose=1000
                              )


# model fitting on training set
multiquantiles_model.fit(X_proper_train, y_proper_train, eval_set=(X_val, y_val))
# Out:
# 0:	learn: 2.2732713	test: 2.3399384	best: 2.3399384 (0)	total: 1.63s	remaining: 4h 31m 52s
# 1000:	learn: 0.3267149	test: 0.3406715	best: 0.3406715 (1000)	total: 26m 3s	remaining: 3h 54m 16s
# 2000:	learn: 0.2317398	test: 0.2615364	best: 0.2615364 (2000)	total: 52m 13s	remaining: 3h 28m 46s
# 3000:	learn: 0.1892721	test: 0.2335313	best: 0.2335313 (3000)	total: 1h 18m 16s	remaining: 3h 2m 33s
# 4000:	learn: 0.1650111	test: 0.2212943	best: 0.2212943 (4000)	total: 1h 44m 27s	remaining: 2h 36m 37s
# 5000:	learn: 0.1477617	test: 0.2145237	best: 0.2145237 (5000)	total: 2h 10m 40s	remaining: 2h 10m 37s
# 6000:	learn: 0.1358559	test: 0.2111125	best: 0.2111125 (6000)	total: 2h 36m 51s	remaining: 1h 44m 31s
# 7000:	learn: 0.1265177	test: 0.2096603	best: 0.2096505 (6967)	total: 3h 3m 4s	remaining: 1h 18m 25s
# 8000:	learn: 0.1185214	test: 0.2089380	best: 0.2089058 (7962)	total: 3h 29m 13s	remaining: 52m 16s
# 9000:	learn: 0.1127355	test: 0.2088753	best: 0.2087669 (8802)	total: 3h 55m 18s	remaining: 26m 6s
# 9999:	learn: 0.1085098	test: 0.2091206	best: 0.2087669 (8802)	total: 4h 21m 12s	remaining: 0us
#
# bestTest = 0.2087669051
# bestIteration = 8802
#
# Shrink model to first 8803 iterations.

# %% [markdown]
# ## Predictions

# %%
predict_cal = multiquantiles_model.predict(X_cal)
predict_val = multiquantiles_model.predict(X_val)
predict_test = multiquantiles_model.predict(kaggle_test_df)

# %% [markdown]
# # F. Conformalized Quantile Regression (CQR)

# %%
for index, (level, q_pair) in enumerate(quantile_mapping.items()):

    print(f'level : {level} interval : [{q_pair[0]} , {q_pair[1]}]\n')

    quantile_regression_calibration_intervals = np.zeros([len(X_cal), 2])
    quantile_regression_calibration_intervals[:, 0] = predict_cal[:, index]
    quantile_regression_calibration_intervals[:, 1] = predict_cal[:, 20 - index]

    conformity_scores = np.max(
    [
        quantile_regression_calibration_intervals[:, 0] - y_cal,
        y_cal - quantile_regression_calibration_intervals[:, 1],
    ],
    axis=0,
    )

    conformity_scores = np.sort(conformity_scores)[::-1]
    
    emperical_quantile = (level/100) * (1 + (1 / len(y_cal)))
    correction_factor = np.quantile(conformity_scores, emperical_quantile, method="higher")
    
    # Plot the histogram
    plt.hist(conformity_scores, bins='auto', color='magenta')

    # Add a vertical line for the
    plt.axvline(correction_factor, color='black', linestyle='dashed', linewidth=1, label='quantile')

    plt.legend()
    plt.xlabel('Calibration Error')
    plt.ylabel('Frequency')
    plt.title('Histogram of Calibration Errors')

    plt.show()

    quantile_regression_prediction_intervals_kaggle = np.zeros([len(kaggle_test_df), 2])
    quantile_regression_prediction_intervals_kaggle[:, 0] = predict_test[:, index]
    quantile_regression_prediction_intervals_kaggle[:, 1] = predict_test[:, 20 - index]

    correction_factor_kaggle = np.ones([len(kaggle_test_df), 2])
    correction_factor_kaggle[:, 0] = correction_factor_kaggle[:, 0] * correction_factor * -1
    correction_factor_kaggle[:, 1] = correction_factor_kaggle[:, 1] * correction_factor

    quantile_regression_prediction_intervals_validation = np.zeros([len(X_val), 2])
    quantile_regression_prediction_intervals_validation[:, 0] = predict_val[:, index]
    quantile_regression_prediction_intervals_validation[:, 1] = predict_val[:, 20 - index]

    correction_factor_validation = np.ones([len(X_val), 2])
    correction_factor_validation[:, 0] = correction_factor_validation[:, 0] * correction_factor * -1
    correction_factor_validation[:, 1] = correction_factor_validation[:, 1] * correction_factor

    submission_df[q_pair[0]] = quantile_regression_prediction_intervals_kaggle[:, 0] + correction_factor_kaggle[:, 0]
    submission_df[q_pair[1]] = quantile_regression_prediction_intervals_kaggle[:, 1] + correction_factor_kaggle[:, 1]

    submission_val_df[q_pair[0]] = quantile_regression_prediction_intervals_validation[:, 0] + correction_factor_validation[:, 0]
    submission_val_df[q_pair[1]] = quantile_regression_prediction_intervals_validation[:, 1] + correction_factor_validation[:, 1]
# Out:
# level : 95 interval : [0.025 , 0.975]
# level : 90 interval : [0.05 , 0.95]
# level : 80 interval : [0.10 , 0.90]
# level : 70 interval : [0.15 , 0.85]
# level : 60 interval : [0.20 , 0.80]
# level : 50 interval : [0.25 , 0.75]
# level : 40 interval : [0.30 , 0.70]
# level : 30 interval : [0.35 , 0.65]
# level : 20 interval : [0.40 , 0.60]
# level : 10 interval : [0.45 , 0.55]

# %%
## Median
submission_df['0.50'] = predict_test[:, 10]
submission_val_df['0.50'] = predict_val[:, 10]

# %%
submission_df
# Out:
#          id      0.025       0.05       0.10       0.15       0.20       0.25  \
# 0     64320  16.900628  14.933022  12.552999  11.238649  10.058240   9.458619
# 1     64321  17.858523  15.713853  13.226710  11.905574  10.730061   9.955344
# 2     64322  17.481946  15.444776  12.697141  11.343191  10.211491   9.481914
# 3     64323  16.207755  14.406686  12.318816  11.137725  10.271290   9.674890
# 4     64324  16.209773  14.463358  12.206406  11.011841  10.278753   9.657484
# ...     ...        ...        ...        ...        ...        ...        ...
# 5355  69675   9.056076   9.644236  10.065974  10.280811  10.351240  10.445433
# 5356  69676   8.887780   9.386616   9.677480   9.909695   9.988123  10.146647
# 5357  69677   8.706011   9.061032   9.351770   9.568352   9.656824   9.765451
# 5358  69678   8.434039   8.944161   9.257934   9.503289   9.638849   9.745986
# 5359  69679   8.466806   8.988675   9.256853   9.443370   9.612849   9.789797
#
#            0.30       0.35       0.40  ...       0.55       0.60       0.65  \
# 0      9.177955   9.254976   8.574518  ...   8.152006   7.563002   7.188625
# 1      9.478034   9.435699   8.659513  ...   7.978117   7.244816   6.700768
# 2      9.117332   9.167319   8.408895  ...   7.979773   7.301242   6.661063
# 3      9.384684   9.424485   8.805365  ...   8.483056   7.842801   7.285477
# 4      9.399989   9.407238   8.649314  ...   7.917463   7.318120   6.848135
# ...         ...        ...        ...  ...        ...        ...        ...
# 5355  10.612839  10.755821  10.852186  ...  11.123952  11.139850  11.157731
# 5356  10.288786  10.482784  10.544368  ...  10.776723  10.800855  10.810057
# 5357   9.888952  10.085905  10.116193  ...  10.349900  10.411797  10.499835
# 5358   9.870309  10.100191  10.150472  ...  10.322367  10.404404  10.481813
# 5359   9.969461  10.171731  10.202514  ...  10.451784  10.512187  10.601471
#
#            0.70       0.75       0.80       0.85       0.90       0.95  \
# 0      7.279278   6.512108   5.890731   5.233813   4.264872   3.044791
# 1      6.701536   5.882827   5.384932   4.622592   3.494297   2.094546
# 2      6.653151   5.819052   5.480919   4.649795   3.583131   2.023325
# 3      6.994066   6.223184   5.821910   5.194623   4.239794   2.804852
# 4      6.800186   6.088600   5.782961   5.131700   4.151023   2.456144
# ...         ...        ...        ...        ...        ...        ...
# 5355  11.334768  11.420019  11.552421  11.600309  11.723338  12.016090
# 5356  10.960215  11.075129  11.221398  11.272892  11.390794  11.742880
# 5357  10.622276  10.735303  10.769789  10.895559  11.058068  11.454259
# 5358  10.680896  10.768744  10.843806  10.962521  11.213933  11.713949
# 5359  10.829853  10.977562  11.120341  11.311049  11.537418  12.019466
#
#           0.975
# 0      1.638932
# 1      0.242547
# 2      0.085295
# 3      1.253138
# 4      0.893439
# ...         ...
# 5355  12.157484
# 5356  11.852732
# 5357  11.570710
# 5358  11.843423
# 5359  12.151978
#
# [5360 rows x 22 columns]

# %% [markdown]
# # G. Prediction Interval (PI) Visualization

# %%
for (level, q_pair) in quantile_mapping.items():

    print(f'level : {level} interval : [{q_pair[0]} , {q_pair[1]} ]\n')
    
    title = 'interval : ' + q_pair[0] + ' - ' + q_pair[1]
    
    # Create a new figure
    plt.figure(figsize=(10, 6))

    # Plot actual values
    plt.plot(submission_df['0.50'], label='median', color='blue')


    # Plot prediction intervals
    plt.fill_between(submission_df.index, submission_df[q_pair[0]], submission_df[q_pair[1]],
                     color='gray', alpha=0.2, label='Prediction Interval')

    # Add the legend
    plt.legend()

    # Set labels and title
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title(title)

    # Show the plot
    plt.show()
# Out:
# level : 95 interval : [0.025 , 0.975 ]
# level : 90 interval : [0.05 , 0.95 ]
# level : 80 interval : [0.10 , 0.90 ]
# level : 70 interval : [0.15 , 0.85 ]
# level : 60 interval : [0.20 , 0.80 ]
# level : 50 interval : [0.25 , 0.75 ]
# level : 40 interval : [0.30 , 0.70 ]
# level : 30 interval : [0.35 , 0.65 ]
# level : 20 interval : [0.40 , 0.60 ]
# level : 10 interval : [0.45 , 0.55 ]

# %% [markdown]
# # E. Evaluation

# %%
# Dataframe with results
y_val = pd.DataFrame(y_val, columns=['Temperature'])
val_df = pd.concat([X_val, y_val], axis=1)

# %%
us.crps(submission_val_df, val_df)
# Out:
# 0.42739842134850775

# %%
us.coverage_report(submission_val_df, val_df)
# Out:
#  Ideal: 95% Actual: 94.79% [FAIL]
#  Ideal: 90% Actual: 90.3% [PASS]
#  Ideal: 80% Actual: 79.98% [FAIL]
#  Ideal: 70% Actual: 69.96% [FAIL]
#  Ideal: 60% Actual: 59.76% [FAIL]
#  Ideal: 50% Actual: 49.14% [FAIL]
#  Ideal: 40% Actual: 40.17% [PASS]
#  Ideal: 30% Actual: 29.87% [FAIL]
#  Ideal: 20% Actual: 20.54% [PASS]
#  Ideal: 10% Actual: 9.35% [FAIL]

# %% [markdown]
# # F. Save Submission to file

# %%
submission_df.to_csv('submission.csv', index=False)

# %% [markdown]
# # End of code
